# %% [markdown]
# ## Interogarea structurilor de date de tip DataFrame in Pandas

# %% [markdown]
# ![geonames.png](../images/geonames.png)
# <!-- <img src="../images/geonames.png" width="300"> -->
#
# Setul de date <i>CountryInfo</i> de la [Geonames](http://api.geonames.org/countryInfoCSV?username=demo) contine informatii generale cu privire la nu mai putin de 252 de tari: coduri ISO, cod FIPS, nume tara, capitala, suprafata, populatie, continent, limbi, valuta, geonameID.

# %%
import pandas as pd

# %%
# lista personalizata de valori NaN; valoarea NA trebuie exclusa din lista implicita
# deoarece in coloana continent valoarea NA se utilizeaza cu semnificatia de North America
# mai mult in coloana continent nu apar valori nule; toate tarile sunt parte a unui continent

na_values = ['', '#N/A', '#N/A N/A', '#NA', '-1.#IND', '-1.#QNAN', '-NaN', '-nan', 
             '1.#IND', '1.#QNAN', 'N/A', 'NULL', 'NaN','n/a', 'nan', 'null']

# %%
# daca keep_default_na are valoare False si este precizata o lista de valori nule 
# acceptate prin na_values, doar aceste valori vor fi avute in vedere la parsare

df = pd.read_csv("http://api.geonames.org/countryInfoCSV?username=demo", sep="\t", header=0, 
                 na_values=na_values, keep_default_na=False,
                 usecols=['iso alpha2', 'iso alpha3', 'iso numeric', 'fips code', 'name',  
                          'capital', 'areaInSqKm', 'population', 'continent', 'currency'])

# %%
df
# Out:
#     iso alpha2 iso alpha3  iso numeric fips code                  name  \
# 0           AD        AND           20        AN               Andorra
# 1           AE        ARE          784        AE  United Arab Emirates
# 2           AF        AFG            4        AF           Afghanistan
# 3           AG        ATG           28        AC   Antigua and Barbuda
# 4           AI        AIA          660        AV              Anguilla
# ..         ...        ...          ...       ...                   ...
# 247         YE        YEM          887        YM                 Yemen
# 248         YT        MYT          175        MF               Mayotte
# 249         ZA        ZAF          710        SF          South Africa
# 250         ZM        ZMB          894        ZA                Zambia
# 251         ZW        ZWE          716        ZI              Zimbabwe
#
#               capital  areaInSqKm  population continent currency
# 0    Andorra la Vella       468.0       77006        EU      EUR
# 1           Abu Dhabi     82880.0     9630959        AS      AED
# 2               Kabul    647500.0    37172386        AS      AFN
# 3           St John's       443.0       96286        NA      XCD
# 4          The Valley       102.0       13254        NA      XCD
# ..                ...         ...         ...       ...      ...
# 247             Sanaa    527970.0    28498687        AS      YER
# 248         Mamoudzou       374.0      279471        AF      EUR
# 249          Pretoria   1219912.0    57779622        AF      ZAR
# 250            Lusaka    752614.0    17351822        AF      ZMW
# 251            Harare    390580.0    14439018        AF      ZWL
#
# [252 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   iso alpha2   252 non-null    object
#  1   iso alpha3   252 non-null    object
#  2   iso numeric  252 non-null    int64
#  3   fips code    249 non-null    object
#  4   name         250 non-null    object
#  5   capital      241 non-null    object
#  6   areaInSqKm   252 non-null    float64
#  7   population   252 non-null    int64
#  8   continent    252 non-null    object
#  9   currency     251 non-null    object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 19.8+ KB

# %%
df.columns
# Out:
# Index(['iso alpha2', 'iso alpha3', 'iso numeric', 'fips code', 'name',
#        'capital', 'areaInSqKm', 'population', 'continent', 'currency'],
#       dtype='object')

# %%
df
# Out:
#     iso alpha2 iso alpha3  iso numeric fips code                  name  \
# 0           AD        AND           20        AN               Andorra
# 1           AE        ARE          784        AE  United Arab Emirates
# 2           AF        AFG            4        AF           Afghanistan
# 3           AG        ATG           28        AC   Antigua and Barbuda
# 4           AI        AIA          660        AV              Anguilla
# ..         ...        ...          ...       ...                   ...
# 247         YE        YEM          887        YM                 Yemen
# 248         YT        MYT          175        MF               Mayotte
# 249         ZA        ZAF          710        SF          South Africa
# 250         ZM        ZMB          894        ZA                Zambia
# 251         ZW        ZWE          716        ZI              Zimbabwe
#
#               capital  areaInSqKm  population continent currency
# 0    Andorra la Vella       468.0       77006        EU      EUR
# 1           Abu Dhabi     82880.0     9630959        AS      AED
# 2               Kabul    647500.0    37172386        AS      AFN
# 3           St John's       443.0       96286        NA      XCD
# 4          The Valley       102.0       13254        NA      XCD
# ..                ...         ...         ...       ...      ...
# 247             Sanaa    527970.0    28498687        AS      YER
# 248         Mamoudzou       374.0      279471        AF      EUR
# 249          Pretoria   1219912.0    57779622        AF      ZAR
# 250            Lusaka    752614.0    17351822        AF      ZMW
# 251            Harare    390580.0    14439018        AF      ZWL
#
# [252 rows x 10 columns]

# %%
df.query("population > 1000000000")
# Out:
#     iso alpha2 iso alpha3  iso numeric fips code   name    capital  \
# 48          CN        CHN          156        CH  China    Beijing
# 106         IN        IND          356        IN  India  New Delhi
#
#      areaInSqKm  population continent currency
# 48    9596960.0  1411778724        AS      CNY
# 106   3287590.0  1352617328        AS      INR

# %%
df.query('not (continent == \'EU\') and (`fips code`.isnull())')
# Out:
#     iso alpha2 iso alpha3  iso numeric fips code  \
# 30          BQ        BES          535       NaN
# 233         UM        UMI          581       NaN
#
#                                   name     capital  areaInSqKm  population  \
# 30   Bonaire, Sint Eustatius, and Saba  Kralendijk       328.0       18012
# 233              U.S. Outlying Islands         NaN         0.0           0
#
#     continent currency
# 30         NA      USD
# 233        OC      USD

# %%
df.query('`fips code` != `fips code`')
# Out:
#     iso alpha2 iso alpha3  iso numeric fips code  \
# 15          AX        ALA          248       NaN
# 30          BQ        BES          535       NaN
# 233         UM        UMI          581       NaN
#
#                                   name     capital  areaInSqKm  population  \
# 15                               Åland   Mariehamn      1580.0       26711
# 30   Bonaire, Sint Eustatius, and Saba  Kralendijk       328.0       18012
# 233              U.S. Outlying Islands         NaN         0.0           0
#
#     continent currency
# 15         EU      EUR
# 30         NA      USD
# 233        OC      USD

# %%
df.query("continent == 'OC'")
# Out:
#     iso alpha2 iso alpha3  iso numeric fips code                      name  \
# 11          AS        ASM           16        AQ            American Samoa
# 13          AU        AUS           36        AS                 Australia
# 45          CK        COK          184        CW              Cook Islands
# 55          CX        CXR          162        KT          Christmas Island
# 72          FJ        FJI          242        FJ                      Fiji
# 74          FM        FSM          583        FM                Micronesia
# 93          GU        GUM          316        GQ                      Guam
# 119         KI        KIR          296        KR                  Kiribati
# 144         MH        MHL          584        RM          Marshall Islands
# 150         MP        MNP          580        CQ  Northern Mariana Islands
# 162         NC        NCL          540        NC             New Caledonia
# 164         NF        NFK          574        NF            Norfolk Island
# 170         NR        NRU          520        NR                     Nauru
# 171         NU        NIU          570        NE                      Niue
# 172         NZ        NZL          554        NZ               New Zealand
# 176         PF        PYF          258        FP          French Polynesia
# 177         PG        PNG          598        PP          Papua New Guinea
# 182         PN        PCN          612        PC          Pitcairn Islands
# 186         PW        PLW          585        PS                     Palau
# 195         SB        SLB           90        BP           Solomon Islands
# 221         TK        TKL          772        TL                   Tokelau
# 222         TL        TLS          626        TT               Timor-Leste
# 225         TO        TON          776        TN                     Tonga
# 228         TV        TUV          798        TV                    Tuvalu
# 233         UM        UMI          581       NaN     U.S. Outlying Islands
# 243         VU        VUT          548        NH                   Vanuatu
# 244         WF        WLF          876        WF         Wallis and Futuna
# 245         WS        WSM          882        WS                     Samoa
#
#               capital  areaInSqKm  population continent currency
# 11          Pago Pago       199.0       55465        OC      USD
# 13           Canberra   7686850.0    24992369        OC      AUD
# 45             Avarua       240.0       21388        OC      NZD
# 55   Flying Fish Cove       135.0        1500        OC      AUD
# 72               Suva     18270.0      883483        OC      FJD
# 74            Palikir       702.0      112640        OC      USD
# 93            Hagåtña       549.0      165768        OC      USD
# 119            Tarawa       811.0      115847        OC      AUD
# 144            Majuro       181.3       58413        OC      USD
# 150            Saipan       477.0       56882        OC      USD
# 162            Noumea     19060.0      284060        OC      XPF
# 164          Kingston        34.6        1828        OC      AUD
# 170    Yaren District        21.0       12704        OC      AUD
# 171             Alofi       260.0        2166        OC      NZD
# 172        Wellington    268680.0     4885500        OC      NZD
# 176           Papeete      4167.0      277679        OC      XPF
# 177      Port Moresby    462840.0     8606316        OC      PGK
# 182         Adamstown        47.0          46        OC      NZD
# 186         Ngerulmud       458.0       17907        OC      USD
# 195           Honiara     28450.0      652858        OC      SBD
# 221               NaN        10.0        1466        OC      NZD
# 222              Dili     15007.0     1267972        OC      USD
# 225        Nuku'alofa       748.0      103197        OC      TOP
# 228          Funafuti        26.0       11508        OC      AUD
# 233               NaN         0.0           0        OC      USD
# 243         Port Vila     12200.0      292680        OC      VUV
# 244          Mata-Utu       274.0       16025        OC      XPF
# 245              Apia      2944.0      196130        OC      WST

# %%
df.query("(continent == 'EU') and (areaInSqKm < 100)")
# Out:
#     iso alpha2 iso alpha3  iso numeric fips code          name        capital  \
# 82          GG        GGY          831        GK      Guernsey  St Peter Port
# 84          GI        GIB          292        GI     Gibraltar      Gibraltar
# 139         MC        MCO          492        MN        Monaco         Monaco
# 205         SM        SMR          674        SM    San Marino     San Marino
# 237         VA        VAT          336        VT  Vatican City   Vatican City
#
#      areaInSqKm  population continent currency
# 82        78.00       65228        EU      GBP
# 84         6.50       33718        EU      GIP
# 139        1.95       38682        EU      EUR
# 205       61.20       33785        EU      EUR
# 237        0.44         921        EU      EUR

# %%
df.query("(continent == 'EU' or continent == 'AS') and (areaInSqKm < 100)")
# Out:
#     iso alpha2 iso alpha3  iso numeric fips code  \
# 39          CC        CCK          166        CK
# 82          GG        GGY          831        GK
# 84          GI        GIB          292        GI
# 107         IO        IOT           86        IO
# 139         MC        MCO          492        MN
# 205         SM        SMR          674        SM
# 237         VA        VAT          336        VT
#
#                                name        capital  areaInSqKm  population  \
# 39          Cocos (Keeling) Islands    West Island       14.00         628
# 82                         Guernsey  St Peter Port       78.00       65228
# 84                        Gibraltar      Gibraltar        6.50       33718
# 107  British Indian Ocean Territory            NaN       60.00        4000
# 139                          Monaco         Monaco        1.95       38682
# 205                      San Marino     San Marino       61.20       33785
# 237                    Vatican City   Vatican City        0.44         921
#
#     continent currency
# 39         AS      AUD
# 82         EU      GBP
# 84         EU      GIP
# 107        AS      USD
# 139        EU      EUR
# 205        EU      EUR
# 237        EU      EUR

# %%
df.query("(continent in ['EU', 'AS', 'OC']) and not (areaInSqKm > 100)")
# Out:
#     iso alpha2 iso alpha3  iso numeric fips code  \
# 39          CC        CCK          166        CK
# 82          GG        GGY          831        GK
# 84          GI        GIB          292        GI
# 107         IO        IOT           86        IO
# 139         MC        MCO          492        MN
# 164         NF        NFK          574        NF
# 170         NR        NRU          520        NR
# 182         PN        PCN          612        PC
# 205         SM        SMR          674        SM
# 221         TK        TKL          772        TL
# 228         TV        TUV          798        TV
# 233         UM        UMI          581       NaN
# 237         VA        VAT          336        VT
#
#                                name         capital  areaInSqKm  population  \
# 39          Cocos (Keeling) Islands     West Island       14.00         628
# 82                         Guernsey   St Peter Port       78.00       65228
# 84                        Gibraltar       Gibraltar        6.50       33718
# 107  British Indian Ocean Territory             NaN       60.00        4000
# 139                          Monaco          Monaco        1.95       38682
# 164                  Norfolk Island        Kingston       34.60        1828
# 170                           Nauru  Yaren District       21.00       12704
# 182                Pitcairn Islands       Adamstown       47.00          46
# 205                      San Marino      San Marino       61.20       33785
# 221                         Tokelau             NaN       10.00        1466
# 228                          Tuvalu        Funafuti       26.00       11508
# 233           U.S. Outlying Islands             NaN        0.00           0
# 237                    Vatican City    Vatican City        0.44         921
#
#     continent currency
# 39         AS      AUD
# 82         EU      GBP
# 84         EU      GIP
# 107        AS      USD
# 139        EU      EUR
# 164        OC      AUD
# 170        OC      AUD
# 182        OC      NZD
# 205        EU      EUR
# 221        OC      NZD
# 228        OC      AUD
# 233        OC      USD
# 237        EU      EUR

# %% [markdown]
# * Interogarea datelor folosind variabile Python

# %%
currency = 'USD'

# %%
df.query('(continent in ("NA", "SA")) and currency == @currency')
# Out:
#     iso alpha2 iso alpha3  iso numeric fips code  \
# 30          BQ        BES          535       NaN
# 64          EC        ECU          218        EC
# 183         PR        PRI          630        RQ
# 211         SV        SLV          222        ES
# 215         TC        TCA          796        TK
# 234         US        USA          840        US
# 240         VG        VGB           92        VI
# 241         VI        VIR          850        VQ
#
#                                   name           capital  areaInSqKm  \
# 30   Bonaire, Sint Eustatius, and Saba        Kralendijk       328.0
# 64                             Ecuador             Quito    283560.0
# 183                        Puerto Rico          San Juan      9104.0
# 211                        El Salvador      San Salvador     21040.0
# 215           Turks and Caicos Islands     Cockburn Town       430.0
# 234                      United States        Washington   9629091.0
# 240             British Virgin Islands         Road Town       153.0
# 241                U.S. Virgin Islands  Charlotte Amalie       352.0
#
#      population continent currency
# 30        18012        NA      USD
# 64     17084357        SA      USD
# 183     3195153        NA      USD
# 211     6420744        NA      USD
# 215       37665        NA      USD
# 234   327167434        NA      USD
# 240       29802        NA      USD
# 241      106977        NA      USD

# %%
percentile = df.population.quantile(0.9)
print(percentile)
# Out:
# 53501081.10000001

# %%
# statele care utilizeaza valuta usd si a caror populatie este mai mare decat 90% din populatia celorlalte state

currencies = ['EUR', 'USD']
df.query('(currency == @currencies) and (population > @percentile)')
# Out:
#     iso alpha2 iso alpha3  iso numeric fips code           name     capital  \
# 58          DE        DEU          276        GM        Germany      Berlin
# 76          FR        FRA          250        FR         France       Paris
# 111         IT        ITA          380        IT          Italy        Rome
# 234         US        USA          840        US  United States  Washington
#
#      areaInSqKm  population continent currency
# 58     357021.0    82927922        EU      EUR
# 76     547030.0    66987244        EU      EUR
# 111    301230.0    60431283        EU      EUR
# 234   9629091.0   327167434        NA      USD

# %%
df.loc[106]
# Out:
# iso alpha2             IN
# iso alpha3            IND
# iso numeric           356
# fips code              IN
# name                India
# capital         New Delhi
# areaInSqKm      3287590.0
# population     1352617328
# continent              AS
# currency              INR
# Name: 106, dtype: object

# %%
df.loc[103:106, 'name']
# Out:
# 103        Ireland
# 104         Israel
# 105    Isle of Man
# 106          India
# Name: name, dtype: object

# %%
df.iloc[106]
# Out:
# iso alpha2             IN
# iso alpha3            IND
# iso numeric           356
# fips code              IN
# name                India
# capital         New Delhi
# areaInSqKm      3287590.0
# population     1352617328
# continent              AS
# currency              INR
# Name: 106, dtype: object

# %%
df.loc[106:107]
# Out:
#     iso alpha2 iso alpha3  iso numeric fips code  \
# 106         IN        IND          356        IN
# 107         IO        IOT           86        IO
#
#                                name    capital  areaInSqKm  population  \
# 106                           India  New Delhi   3287590.0  1352617328
# 107  British Indian Ocean Territory        NaN        60.0        4000
#
#     continent currency
# 106        AS      INR
# 107        AS      USD

# %%
df.iloc[106:109]
# Out:
#     iso alpha2 iso alpha3  iso numeric fips code  \
# 106         IN        IND          356        IN
# 107         IO        IOT           86        IO
# 108         IQ        IRQ          368        IZ
#
#                                name    capital  areaInSqKm  population  \
# 106                           India  New Delhi   3287590.0  1352617328
# 107  British Indian Ocean Territory        NaN        60.0        4000
# 108                            Iraq    Baghdad    437072.0    38433600
#
#     continent currency
# 106        AS      INR
# 107        AS      USD
# 108        AS      IQD

# %%
df.iloc[103:106, 4]
# Out:
# 103        Ireland
# 104         Israel
# 105    Isle of Man
# Name: name, dtype: object

# %%
df.loc[df['population'] > 1000000000]
# Out:
#     iso alpha2 iso alpha3  iso numeric fips code   name    capital  \
# 48          CN        CHN          156        CH  China    Beijing
# 106         IN        IND          356        IN  India  New Delhi
#
#      areaInSqKm  population continent currency
# 48    9596960.0  1411778724        AS      CNY
# 106   3287590.0  1352617328        AS      INR

# %%
mask = df['population'] > 1000000000
print(mask)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 247    False
# 248    False
# 249    False
# 250    False
# 251    False
# Name: population, Length: 252, dtype: bool

# %%
mask[[48, 106]]
# Out:
# 48     True
# 106    True
# Name: population, dtype: bool

# %%
df.loc[mask]
# Out:
#     iso alpha2 iso alpha3  iso numeric fips code   name    capital  \
# 48          CN        CHN          156        CH  China    Beijing
# 106         IN        IND          356        IN  India  New Delhi
#
#      areaInSqKm  population continent currency
# 48    9596960.0  1411778724        AS      CNY
# 106   3287590.0  1352617328        AS      INR

# %%
df[mask]
# Out:
#     iso alpha2 iso alpha3  iso numeric fips code   name    capital  \
# 48          CN        CHN          156        CH  China    Beijing
# 106         IN        IND          356        IN  India  New Delhi
#
#      areaInSqKm  population continent currency
# 48    9596960.0  1411778724        AS      CNY
# 106   3287590.0  1352617328        AS      INR

# %%
df.loc[df['population'] > 1000000000, ['iso alpha2', 'iso numeric', 'name', 'capital', 'population', 'continent', 'currency']]
# Out:
#     iso alpha2  iso numeric   name    capital  population continent currency
# 48          CN          156  China    Beijing  1411778724        AS      CNY
# 106         IN          356  India  New Delhi  1352617328        AS      INR

# %%
mask = (df.iloc[:, 7] > 1000000000)

# %%
df[mask]
# Out:
#     iso alpha2 iso alpha3  iso numeric fips code   name    capital  \
# 48          CN        CHN          156        CH  China    Beijing
# 106         IN        IND          356        IN  India  New Delhi
#
#      areaInSqKm  population continent currency
# 48    9596960.0  1411778724        AS      CNY
# 106   3287590.0  1352617328        AS      INR

# %%
result = df.nlargest(2, 'population')
print(result)
# Out:
#     iso alpha2 iso alpha3  iso numeric fips code   name    capital  \
# 48          CN        CHN          156        CH  China    Beijing
# 106         IN        IND          356        IN  India  New Delhi
#
#      areaInSqKm  population continent currency
# 48    9596960.0  1411778724        AS      CNY
# 106   3287590.0  1352617328        AS      INR

# %%
df.nsmallest(2, 'population')
# Out:
#    iso alpha2 iso alpha3  iso numeric fips code           name capital  \
# 9          AQ        ATA           10        AY     Antarctica     NaN
# 34         BV        BVT           74        BV  Bouvet Island     NaN
#
#     areaInSqKm  population continent currency
# 9   14000000.0           0        AN      NaN
# 34        49.0           0        AN      NOK

# %%
mask = (df['name'].str.contains('Island')) & (df['continent'].isin(['OC'])) & (df['currency'] == 'USD')

# %%
result = df[mask]
print(result)
# Out:
#     iso alpha2 iso alpha3  iso numeric fips code                      name  \
# 144         MH        MHL          584        RM          Marshall Islands
# 150         MP        MNP          580        CQ  Northern Mariana Islands
# 233         UM        UMI          581       NaN     U.S. Outlying Islands
#
#     capital  areaInSqKm  population continent currency
# 144  Majuro       181.3       58413        OC      USD
# 150  Saipan       477.0       56882        OC      USD
# 233     NaN         0.0           0        OC      USD
